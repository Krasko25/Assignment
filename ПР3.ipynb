# %%
import numpy as np
import matplotlib.pyplot as plt
from tensorflow import keras
from google.colab import files
from io import BytesIO
from PIL import Image

# Инициализация модели VGG16
model = keras.applications.VGG16()

# Загрузка файла изображения с помощью Google Colab
uploaded = files.upload()

# Открывается и отображается загруженное изображение
img = Image.open(BytesIO(uploaded[list(uploaded.keys())[0]]))
plt.imshow(img)

# Преобразование изображения в массив
img = np.array(img)

# Предварительная обработка изображения для использования с VGG16
x = keras.applications.vgg16.preprocess_input(img)

# Вывод формы массива x (преобразованного изображения)
print(x.shape)

# Расширение массива x в измерении (оси) 0
x = np.expand_dims(x, axis=0)

# Предсказание модели VGG16
res = model.predict(x)

# Вывод индекса класса с наибольшей вероятностью
print(np.argmax(res))

# %% [markdown]
# # VGG16

# %% [markdown]
# Найдём милое изображение:
#
# ![image.jpg](data:image/jpeg;base64,...)

# %% [markdown]
# Нужные пакеты указаны в файле readme.txt
#
# Подключаем нужные библиотеки:

# %%
import numpy as np
import matplotlib.pyplot as plt
from tensorflow import keras
from google.colab import files
from io import BytesIO
from PIL import Image

# %% [markdown]
# Инициализируем модель сети VGG16 с параметрами по умолчанию:

# %%
model = keras.applications.VGG16()

# %% [markdown]
# Загрузка изображения:

# %%
# Загрузка файла изображения с помощью Google Colab
uploaded = files.upload()

# Открывается и отображается загруженное изображение
img = Image.open(BytesIO(uploaded[list(uploaded.keys())[0]]))
plt.imshow(img)

# %% [markdown]
# Приводим изображение к нужному формату:

# %%
# Преобразование изображения в массив
img = np.array(img)

# Предварительная обработка изображения для использования с VGG16
x = keras.applications.vgg16.preprocess_input(img)

# Вывод формы массива x (преобразованного изображения)
print(x.shape)

# Расширение массива x в измерении (оси) 0
x = np.expand_dims(x, axis=0)

# %% [markdown]
# Выводим результат:

# %%
# Предсказание модели VGG16
res = model.predict(x)

# Вывод индекса класса с наибольшей вероятностью
print(np.argmax(res))
# Out:
# 1/1 [==============================] - 1s 739ms/step
# 162

# %% [markdown]
# В результате мы получили индекс 162, что соответствует гончей, ищейке.
#
# ![Screenshot 2023-08-10 at 12.58.50.png](data:image/png;base64,...)![Screenshot 2023-08-10 at 12.56.33.png](data:image/png;base64,...)

# %% [markdown]
# # VGG19

# %% [markdown]
# Реализуем эту же программу, но с использованием VGG19. Код будет отличать только двумя строками:

# %%
import numpy as np
import matplotlib.pyplot as plt
from tensorflow import keras
from google.colab import files
from io import BytesIO
from PIL import Image

# Инициализация модели VGG19
model = keras.applications.VGG19()

# Загрузка файла изображения с помощью Google Colab
uploaded = files.upload()

# Открывается и отображается загруженное изображение
img = Image.open(BytesIO(uploaded[list(uploaded.keys())[0]]))
plt.imshow(img)

# Преобразование изображения в массив
img = np.array(img)

# Предварительная обработка изображения для использования с VGG19
x = keras.applications.vgg19.preprocess_input(img)

# Вывод формы массива x (преобразованного изображения)
print(x.shape)

# Расширение массива x в измерении (оси) 0
x = np.expand_dims(x, axis=0)

# Предсказание модели VGG19
res = model.predict(x)

# Вывод индекса класса с наибольшей вероятностью
print(np.argmax(res))

# %% [markdown]
# Результатом выполнения этой программы на том же изображении стал идентичный результат - id 162, гончая, ищейка.
